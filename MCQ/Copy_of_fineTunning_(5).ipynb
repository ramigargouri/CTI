# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# We have to check which Torch version for Xformers (2.3 -> 0.0.27)
from torch import __version__; from packaging.version import Version as V
xformers = "xformers==0.0.27" if V(__version__) < V("2.4.0") else "xformers"
# !pip install --no-deps {xformers} trl peft accelerate bitsandbytes triton

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    token = ""
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth 2024.8: Fast Llama patching. Transformers = 4.44.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.27. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
import pandas as pd
import json

# Load the TSV file
df = pd.read_csv('/content/output_questions (2).tsv', sep='\t')
df.columns = df.columns.str.strip()

# Create a list to hold the JSON objects
data = []

# Process each row in the DataFrame
for _, row in df.iterrows():
    entry = {
        'question': row['Question'],
        'options': {
            'A': row['Option A'],
            'B': row['Option B'],
            'C': row['Option C'],
            'D': row['Option D']
        },
        'correct_answer': row['Correct Answer']
    }
    data.append(entry)

# Save to JSONL file
with open('/content/dataJson.jsonl', 'w') as f:
    for item in data:
        f.write(json.dumps(item) + '\n')

# %%
import json

input_file = "/content/dataJson.jsonl"
output_file = "/content/cleaned_dataJson.jsonl"

# Function to sanitize options (convert all option values to strings)
def sanitize_options(options):
    for key, value in options.items():
        options[key] = str(value)  # Ensure all options are strings
    return options

# Open the original dataset and the output file
with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
    for line in infile:
        try:
            # Parse each line as JSON
            example = json.loads(line)

            # Sanitize the 'options' field
            if 'options' in example:
                example['options'] = sanitize_options(example['options'])

            # Write the sanitized example back to the new file
            outfile.write(json.dumps(example) + "\n")
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            continue  # Skip any lines with JSON errors

print("Dataset has been cleaned and saved to", output_file)
# Out:
# Dataset has been cleaned and saved to /content/cleaned_dataJson.jsonl

# %%
import json

input_file_path = '/content/cleaned_dataJson.jsonl'
output_file_path = '/content/cleaned_dataJson_fixed.jsonl'

with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    for line in infile:
        try:
            record = json.loads(line)
            # Ensure 'question' and 'correct_answer' are strings
            if 'question' in record:
                record['question'] = str(record['question'])
            if 'correct_answer' in record:
                record['correct_answer'] = str(record['correct_answer'])
            # Write the fixed record to the new file
            json.dump(record, outfile)
            outfile.write('\n')
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
        except Exception as e:
            print(f"Error processing record: {e}")

print(f"Preprocessing complete. Fixed file saved as {output_file_path}")
# Out:
# Preprocessing complete. Fixed file saved as /content/cleaned_dataJson_fixed.jsonl

# %%
# Use the fixed JSONL file
file_path = "/content/cleaned_dataJson_fixed.jsonl"

# Load and format the dataset
try:
    dataset = load_dataset("json", data_files={"train": file_path}, split="train")
    # Apply the formatting function to the dataset with batching for efficiency
    formatted_dataset = dataset.map(formatting_prompts_func, batched=True)

    # Print the first formatted example to verify
    print(f"Formatted text: {formatted_dataset[0]['text']}")
except Exception as e:
    print(f"Dataset generation error: {e}")
# Out:
# Formatted text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary directly interacting with a victim to manipulate them into divulging confidential information?
# Options:
# A: Spearphishing Attachment (T1193)
# B: Social Engineering (T1140)
# C: Remote Access Tools (T1219)
# D: Man-in-the-Middle Attack (T1557)
# The correct answer is B.

# %%
import re
from typing import Dict, Any, List
from datasets import load_dataset

def formatting_prompts_func(examples: Dict[str, Any]) -> Dict[str, Any]:
    questions = examples["question"]
    options = examples["options"]
    correct_answers = examples["correct_answer"]
    texts = []

    for question, option, correct_answer in zip(questions, options, correct_answers):
        try:
            # Print the raw data to ensure it's correct (for debugging)
            print(f"Processing question: {question}")
            print(f"Options: {option}")
            print(f"Correct answer: {correct_answer}")

            # Ensure the dictionary has the required keys and correct_answer is a string
            if isinstance(option, dict) and all(k in option for k in ['A', 'B', 'C', 'D']):
                instruction = "Answer the following multiple-choice question."
                input_text = f"{question}\nOptions:\nA: {option['A']}\nB: {option['B']}\nC: {option['C']}\nD: {option['D']}"
                # Convert correct_answer to string
                output = f"The correct answer is {str(correct_answer)}."
                text = f"{instruction}\n{input_text}\n{output}"  # Removed alpaca_prompt.format and EOS_TOKEN
                texts.append(text)
                print(f"Generated text: {text}")
            else:
                print(f"Skipping example with missing or invalid options: {option}")
        except Exception as e:
            print(f"Error processing question: {e}")

    return {"text": texts}

# Check if file exists and is readable
import os
file_path = "/content/cleaned_dataJson_fixed.jsonl"
if not os.path.isfile(file_path):
    raise FileNotFoundError(f"The file {file_path} does not exist or is not accessible.")

# Load and format the dataset
try:
    dataset = load_dataset("json", data_files={"train": file_path}, split="train")
    # Apply the formatting function to the dataset with batching for efficiency
    formatted_dataset = dataset.map(formatting_prompts_func, batched=True)

    # Print the first formatted example to verify
    print(f"Formatted text: {formatted_dataset[0]['text']}")
except Exception as e:
    print(f"Dataset generation error: {e}")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/2518 [00:00<?, ? examples/s]
# Streaming output truncated to the last 5000 lines.
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary utilizing software that is built into a system to take advantage of a trust relationship, bypassing the normal security mechanisms?
# Options:
# A:  A. Valid Accounts
# B:  B. Exploit Public-Facing Application
# C:  C. System Owner/User Discovery
# D:  D. Use Alternate Authentication Material
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary collecting sensitive information from the victim's machine using a keylogger?
# Options: {'A': 'Process Discovery', 'B': 'Clipboard Data', 'C': 'Audio Capture', 'D': 'Credential Dump'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary collecting sensitive information from the victim's machine using a keylogger?
# Options:
# A: Process Discovery
# B: Clipboard Data
# C: Audio Capture
# D: Credential Dump
# The correct answer is B.
# Processing question: Based on the MITRE ATT&CK framework for Enterprise, which technique involves the use of legitimate network administration tools to move laterally within a network?
# Options: {'A': 'Remote File Copy (T1105 - Ingress Tool Transfer)', 'B': 'Valid Accounts (T1078 - Valid Accounts)', 'C': 'Remote Desktop Protocol (T1076 - Remote Desktop Protocol)', 'D': 'Remote Services (T1021 - Remote Services)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Based on the MITRE ATT&CK framework for Enterprise, which technique involves the use of legitimate network administration tools to move laterally within a network?
# Options:
# A: Remote File Copy (T1105 - Ingress Tool Transfer)
# B: Valid Accounts (T1078 - Valid Accounts)
# C: Remote Desktop Protocol (T1076 - Remote Desktop Protocol)
# D: Remote Services (T1021 - Remote Services)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique is associated with the use of software that can enable additional functionality on a compromised system without interacting with the kernel?
# Options: {'A': 'Process Injection (T1055)', 'B': 'Execution through API (T1106)', 'C': 'Component Object Model Hijacking (T1122)', 'D': 'Accessibility Features (T1015)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique is associated with the use of software that can enable additional functionality on a compromised system without interacting with the kernel?
# Options:
# A: Process Injection (T1055)
# B: Execution through API (T1106)
# C: Component Object Model Hijacking (T1122)
# D: Accessibility Features (T1015)
# The correct answer is C.
# Processing question: Based on the MITRE ATT&CK document for Enterprise, which technique involves an adversary manipulating data to be encrypted in such a way that it can only be recovered by paying a ransom to the adversary?
# Options: {'A': 'Ransomware (T1486) - Data Encrypted for Impact', 'B': 'Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol', 'C': 'Data Manipulation (T1565) - Data Manipulation', 'D': 'Valid Accounts (T1078) - Valid Accounts'}
# Correct answer: Ransomware (T1486) - Data Encrypted for Impact
# Generated text: Answer the following multiple-choice question.
# Based on the MITRE ATT&CK document for Enterprise, which technique involves an adversary manipulating data to be encrypted in such a way that it can only be recovered by paying a ransom to the adversary?
# Options:
# A: Ransomware (T1486) - Data Encrypted for Impact
# B: Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol
# C: Data Manipulation (T1565) - Data Manipulation
# D: Valid Accounts (T1078) - Valid Accounts
# The correct answer is Ransomware (T1486) - Data Encrypted for Impact.
# Processing question: Which MITRE ATT&CK technique involves an adversary using tools that are not natively present on the target system and may involve dropping files to disk or executing directly from memory?
# Options: {'A': 'Execution through API (T1106 - Execution through API)', 'B': 'Trusted Relationship (T1199 - Trusted Relationship)', 'C': 'Remote Services (T1021 - Remote Services)', 'D': 'Valid Accounts (T1078 - Valid Accounts)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using tools that are not natively present on the target system and may involve dropping files to disk or executing directly from memory?
# Options:
# A: Execution through API (T1106 - Execution through API)
# B: Trusted Relationship (T1199 - Trusted Relationship)
# C: Remote Services (T1021 - Remote Services)
# D: Valid Accounts (T1078 - Valid Accounts)
# The correct answer is A.
# Processing question: Which technique from the MITRE ATT&CK framework could be leveraged by threat actors to manipulate an organization's perception of reality through the alteration of raw sensor data?
# Options: {'A': 'T1218 - Signed Binary Proxy Execution', 'B': 'T1066 - Adversary OPSEC', 'C': 'T1561 - Disk Content Wipe', 'D': 'T1566 - Phishing'}
# Correct answer: L
# Generated text: Answer the following multiple-choice question.
# Which technique from the MITRE ATT&CK framework could be leveraged by threat actors to manipulate an organization's perception of reality through the alteration of raw sensor data?
# Options:
# A: T1218 - Signed Binary Proxy Execution
# B: T1066 - Adversary OPSEC
# C: T1561 - Disk Content Wipe
# D: T1566 - Phishing
# The correct answer is L.
# Processing question: In MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating an API to control a system?
# Options: {'A': 'Process Injection (T1055) - Process Hollowing', 'B': 'Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol', 'C': 'API Monitoring (T1104) - API Monitoring', 'D': 'Scripting (T1064) - Scripting'}
# Correct answer: T1104 - API Monitoring
# Generated text: Answer the following multiple-choice question.
# In MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating an API to control a system?
# Options:
# A: Process Injection (T1055) - Process Hollowing
# B: Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol
# C: API Monitoring (T1104) - API Monitoring
# D: Scripting (T1064) - Scripting
# The correct answer is T1104 - API Monitoring.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an attacker sending email that includes malicious attachments to a target with the intent of gaining access to the victim's system?
# Options: {'A': 'Reconnaissance: Phishing for Information', 'B': 'Execution: Phishing', 'C': 'Defense Evasion: Spearphishing Attachment', 'D': 'Initial Access: Phishing for Credentials'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an attacker sending email that includes malicious attachments to a target with the intent of gaining access to the victim's system?
# Options:
# A: Reconnaissance: Phishing for Information
# B: Execution: Phishing
# C: Defense Evasion: Spearphishing Attachment
# D: Initial Access: Phishing for Credentials
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary sending unsolicited emails with malicious attachments to compromise a target's system?
# Options: {'A': 'Initial Access: Spearphishing Attachment', 'B': 'Execution: User Execution', 'C': 'Defense Evasion: Masquerading', 'D': 'Exfiltration: Data Compressed'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary sending unsolicited emails with malicious attachments to compromise a target's system?
# Options:
# A: Initial Access: Spearphishing Attachment
# B: Execution: User Execution
# C: Defense Evasion: Masquerading
# D: Exfiltration: Data Compressed
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique is commonly associated with the use of compromised credentials for initial access in the Enterprise environment?
# Options: {'A': '(A) T1190 - Exploit Public-Facing Application', 'B': '(B) T1078 - Valid Accounts', 'C': '(C) T1003 - OS Credential Dumping', 'D': '(D) T1110 - Brute Force'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique is commonly associated with the use of compromised credentials for initial access in the Enterprise environment?
# Options:
# A: (A) T1190 - Exploit Public-Facing Application
# B: (B) T1078 - Valid Accounts
# C: (C) T1003 - OS Credential Dumping
# D: (D) T1110 - Brute Force
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique is specifically designed to prevent an adversary from obtaining sensitive information through searching for plaintext passwords stored in a system?
# Options: {'A': 'Exfiltration Over Alternative Protocol (T1048)', 'B': 'Valid Accounts (T1078)', 'C': 'Obfuscated Files or Information (T1027)', 'D': 'Credential Dumping (T1003)'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique is specifically designed to prevent an adversary from obtaining sensitive information through searching for plaintext passwords stored in a system?
# Options:
# A: Exfiltration Over Alternative Protocol (T1048)
# B: Valid Accounts (T1078)
# C: Obfuscated Files or Information (T1027)
# D: Credential Dumping (T1003)
# The correct answer is D.
# Processing question: Which technique from MITRE ATT&CK (Enterprise) involves an attacker gaining unauthorized access to a system by exploiting a vulnerability in a web server?
# Options: {'A': 'Web Shell (T1100)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Valid Accounts (T1078)', 'D': 'Exploitation for Client Execution (T1203)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which technique from MITRE ATT&CK (Enterprise) involves an attacker gaining unauthorized access to a system by exploiting a vulnerability in a web server?
# Options:
# A: Web Shell (T1100)
# B: Exploit Public-Facing Application (T1190)
# C: Valid Accounts (T1078)
# D: Exploitation for Client Execution (T1203)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves manipulating input to execute arbitrary code on a target system, often through a vulnerable application?
# Options: {'A': 'Execution via API', 'B': 'Exploit Public-Facing Application', 'C': 'Scripting', 'D': 'Process Injection'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves manipulating input to execute arbitrary code on a target system, often through a vulnerable application?
# Options:
# A: Execution via API
# B: Exploit Public-Facing Application
# C: Scripting
# D: Process Injection
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an attacker leveraging malicious Flash content to exploit vulnerabilities in a web browser?
# Options: {'A': '(A) Drive-by Compromise', 'B': '(B) Exploit Public-Facing Application', 'C': '(C) Exploit Client Software', 'D': '(D) Spearphishing Attachment'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker leveraging malicious Flash content to exploit vulnerabilities in a web browser?
# Options:
# A: (A) Drive-by Compromise
# B: (B) Exploit Public-Facing Application
# C: (C) Exploit Client Software
# D: (D) Spearphishing Attachment
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary leveraging trusted network relationships to gain access to a secondary victim located in the same network as the primary victim?
# Options: {'A': 'Exfiltration Over Alternative Protocol (T1048)', 'B': 'Spearphishing Attachment (T1193)', 'C': 'Valid Accounts (T1078)', 'D': 'Man-in-the-Middle (T1557)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary leveraging trusted network relationships to gain access to a secondary victim located in the same network as the primary victim?
# Options:
# A: Exfiltration Over Alternative Protocol (T1048)
# B: Spearphishing Attachment (T1193)
# C: Valid Accounts (T1078)
# D: Man-in-the-Middle (T1557)
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary collecting data from keylogging software and exfiltrating it using non-standard protocols?
# Options: {'A': 'Keylogging (T1056)', 'B': 'Exfiltration Over C2 Channel (T1041)', 'C': 'Data from Local System (T1005)', 'D': 'Exfiltration Over Other Network Medium (T1011)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary collecting data from keylogging software and exfiltrating it using non-standard protocols?
# Options:
# A: Keylogging (T1056)
# B: Exfiltration Over C2 Channel (T1041)
# C: Data from Local System (T1005)
# D: Exfiltration Over Other Network Medium (T1011)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary creating a new account to maintain access without using valid credentials?
# Options: {'A': 'Revert Access Control', 'B': 'Valid Accounts', 'C': 'Account Manipulation', 'D': 'Exploitation for Credential Access'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary creating a new account to maintain access without using valid credentials?
# Options:
# A: Revert Access Control
# B: Valid Accounts
# C: Account Manipulation
# D: Exploitation for Credential Access
# The correct answer is C.
# Processing question: In the context of MITRE ATT&CK for Enterprise, what technique involves an adversary using malicious software to create a persistence mechanism on a system, such as a malicious service or scheduled task?
# Options: {'A': 'Service Execution', 'B': 'Service Stop', 'C': 'Service Creation', 'D': 'Service Modification'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, what technique involves an adversary using malicious software to create a persistence mechanism on a system, such as a malicious service or scheduled task?
# Options:
# A: Service Execution
# B: Service Stop
# C: Service Creation
# D: Service Modification
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary manipulating system memory to evade detection and achieve persistence?
# Options: {'A': 'Process Injection (T1055)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Memory Corruption (T1485)', 'D': 'Indicator Removal on Host (T1070)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating system memory to evade detection and achieve persistence?
# Options:
# A: Process Injection (T1055)
# B: Exploit Public-Facing Application (T1190)
# C: Memory Corruption (T1485)
# D: Indicator Removal on Host (T1070)
# The correct answer is C.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using various methods to hide the presence of their activities on a system?
# Options: {'A': 'Process Injection (T1055) - Process Hollowing', 'B': 'Defense Evasion (T1211) - Exploitation for Defense Evasion', 'C': 'Defense Evasion (T1211) - Indicator Removal on Host', 'D': 'Credential Dumping (T1003) - NTDSutil'}
# Correct answer: Defense Evasion (T1211) - Indicator Removal on Host
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using various methods to hide the presence of their activities on a system?
# Options:
# A: Process Injection (T1055) - Process Hollowing
# B: Defense Evasion (T1211) - Exploitation for Defense Evasion
# C: Defense Evasion (T1211) - Indicator Removal on Host
# D: Credential Dumping (T1003) - NTDSutil
# The correct answer is Defense Evasion (T1211) - Indicator Removal on Host.
# Processing question: Which MITRE ATT&CK technique involves an attacker using a crafted file to gain unauthorized access to a system by exploiting vulnerabilities in the file parser component of a target application on the Enterprise platform?
# Options: {'A': 'Spearphishing Attachment', 'B': 'Exploit Public-Facing Application', 'C': 'Exploitation for Client Execution', 'D': 'Exploitation of Remote Services'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker using a crafted file to gain unauthorized access to a system by exploiting vulnerabilities in the file parser component of a target application on the Enterprise platform?
# Options:
# A: Spearphishing Attachment
# B: Exploit Public-Facing Application
# C: Exploitation for Client Execution
# D: Exploitation of Remote Services
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves a threat actor using a specially crafted email attachment to exploit a vulnerability in the victim's system?
# Options: {'A': 'Spearphishing Attachment', 'B': 'Exploit Public-Facing Application', 'C': 'Remote Access Tools', 'D': 'Valid Accounts'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves a threat actor using a specially crafted email attachment to exploit a vulnerability in the victim's system?
# Options:
# A: Spearphishing Attachment
# B: Exploit Public-Facing Application
# C: Remote Access Tools
# D: Valid Accounts
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves adversaries manipulating time stamps to conceal their activities?
# Options: {'A': 'Process Injection (T1055)', 'B': 'Indicator Removal on Host (T1070)', 'C': 'Obfuscated Files or Information (T1027)', 'D': 'Deobfuscate/Decode Files or Information (T1140)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves adversaries manipulating time stamps to conceal their activities?
# Options:
# A: Process Injection (T1055)
# B: Indicator Removal on Host (T1070)
# C: Obfuscated Files or Information (T1027)
# D: Deobfuscate/Decode Files or Information (T1140)
# The correct answer is B.
# Processing question: What MITRE ATT&CK technique involves an adversary manipulating network infrastructure to redirect traffic?
# Options: {'A': 'Protocol Impersonation (T1093)', 'B': 'Man-in-the-Middle (T1557)', 'C': 'DNS Redirection (T1568)', 'D': 'Connection Proxy (T1090)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# What MITRE ATT&CK technique involves an adversary manipulating network infrastructure to redirect traffic?
# Options:
# A: Protocol Impersonation (T1093)
# B: Man-in-the-Middle (T1557)
# C: DNS Redirection (T1568)
# D: Connection Proxy (T1090)
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary manipulating communication protocols in order to evade detection?
# Options: {'A': 'Protocol Tunneling (T1572)', 'B': 'Process Injection (T1055)', 'C': 'Standard Cryptographic Protocol (T1025)', 'D': 'Exploitation for Defense Evasion (T1211)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating communication protocols in order to evade detection?
# Options:
# A: Protocol Tunneling (T1572)
# B: Process Injection (T1055)
# C: Standard Cryptographic Protocol (T1025)
# D: Exploitation for Defense Evasion (T1211)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary performing actions that allow them to gather information about a specific target without the target's knowledge, such as compromising a third-party resource utilized by the target?
# Options: {'A': 'Reconnaissance: Active Scanning (T1595)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Obtain Capabilities/Tools (T1588)', 'D': 'Valid Accounts (T1078)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary performing actions that allow them to gather information about a specific target without the target's knowledge, such as compromising a third-party resource utilized by the target?
# Options:
# A: Reconnaissance: Active Scanning (T1595)
# B: Exploit Public-Facing Application (T1190)
# C: Obtain Capabilities/Tools (T1588)
# D: Valid Accounts (T1078)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary sending a text message containing a malicious link to a target mobile device?
# Options: {'A': '(A) Spearphishing via Service', 'B': '(B) Messaging Application', 'C': '(C) Mobile Phishing', 'D': '(D) Spearphishing via Text Message'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary sending a text message containing a malicious link to a target mobile device?
# Options:
# A: (A) Spearphishing via Service
# B: (B) Messaging Application
# C: (C) Mobile Phishing
# D: (D) Spearphishing via Text Message
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an attacker exploiting a weakness in a third-party software to gain unauthorized access to a target system?
# Options: {'A': 'Process Injection (T1055)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Exploitation for Privilege Escalation (T1068)', 'D': 'Exploitation for Client Execution (T1203)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker exploiting a weakness in a third-party software to gain unauthorized access to a target system?
# Options:
# A: Process Injection (T1055)
# B: Exploit Public-Facing Application (T1190)
# C: Exploitation for Privilege Escalation (T1068)
# D: Exploitation for Client Execution (T1203)
# The correct answer is B.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating the execution flow of an application by inserting malicious code at the beginning or end of a function?
# Options: {'A': 'Process Injection: Dynamic-link Library Injection (T1055.001)', 'B': 'Lateral Tool Transfer: Remote Desktop Protocol (T1210.002)', 'C': 'Defense Evasion: Masquerading (T1036)', 'D': 'Code Injection: Command-Line Interface (T1059.003)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating the execution flow of an application by inserting malicious code at the beginning or end of a function?
# Options:
# A: Process Injection: Dynamic-link Library Injection (T1055.001)
# B: Lateral Tool Transfer: Remote Desktop Protocol (T1210.002)
# C: Defense Evasion: Masquerading (T1036)
# D: Code Injection: Command-Line Interface (T1059.003)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary modifying software repositories to distribute malicious software updates?
# Options: {'A': 'Software Manipulation', 'B': 'Valid Accounts', 'C': 'Spearphishing Attachment', 'D': 'Trusted Relationship'}
# Correct answer: Software Manipulation
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary modifying software repositories to distribute malicious software updates?
# Options:
# A: Software Manipulation
# B: Valid Accounts
# C: Spearphishing Attachment
# D: Trusted Relationship
# The correct answer is Software Manipulation.
# Processing question: Which MITRE ATT&CK technique involves an attacker manipulating data to cause a denial of service in an ICS environment?
# Options: {'A': 'Process Injection - Dynamic-link Library Injection', 'B': 'External Remote Services', 'C': 'Valid Accounts - Default Accounts', 'D': 'Access Token Manipulation'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker manipulating data to cause a denial of service in an ICS environment?
# Options:
# A: Process Injection - Dynamic-link Library Injection
# B: External Remote Services
# C: Valid Accounts - Default Accounts
# D: Access Token Manipulation
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary manipulating the runtime environment to hide malicious activities, specifically on the Windows platform?
# Options: {'A': 'Process Injection - T1055', 'B': 'Process Discovery - T1057', 'C': 'Obfuscated Files or Information - T1027', 'D': 'Indicator Removal on Host - T1070'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating the runtime environment to hide malicious activities, specifically on the Windows platform?
# Options:
# A: Process Injection - T1055
# B: Process Discovery - T1057
# C: Obfuscated Files or Information - T1027
# D: Indicator Removal on Host - T1070
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary using a malicious DLL to maintain persistence on a Windows system?
# Options: {'A': 'Process Injection - Dynamic-Link Library Injection (T1055)', 'B': 'Exfiltration Over Alternative Protocol (T1048)', 'C': 'Exploitation for Client Execution (T1203)', 'D': 'Remote File Copy (T1105)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using a malicious DLL to maintain persistence on a Windows system?
# Options:
# A: Process Injection - Dynamic-Link Library Injection (T1055)
# B: Exfiltration Over Alternative Protocol (T1048)
# C: Exploitation for Client Execution (T1203)
# D: Remote File Copy (T1105)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an attacker manipulating information sent between two parties without their knowledge by intercepting and altering the communication, often in real-time?
# Options: {'A': 'T1562 - Impair Defenses', 'B': ' T1559 - Inter-Process Communication', 'C': ' T1588 - Compromise Infrastructure', 'D': ' T1587 - Forced Authentication'}
# Correct answer: T1559 - Inter-Process Communication
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker manipulating information sent between two parties without their knowledge by intercepting and altering the communication, often in real-time?
# Options:
# A: T1562 - Impair Defenses
# B:  T1559 - Inter-Process Communication
# C:  T1588 - Compromise Infrastructure
# D:  T1587 - Forced Authentication
# The correct answer is T1559 - Inter-Process Communication.
# Processing question: Which MITRE ATT&CK technique involves the adversary using valid accounts to interact with the target network?
# Options: {'A': 'T1078 - Valid Accounts', 'B': 'T1059 - Command-Line Interface', 'C': 'T1003 - OS Credential Dumping', 'D': 'T1105 - Ingress Tool Transfer'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves the adversary using valid accounts to interact with the target network?
# Options:
# A: T1078 - Valid Accounts
# B: T1059 - Command-Line Interface
# C: T1003 - OS Credential Dumping
# D: T1105 - Ingress Tool Transfer
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary using malicious documents to deliver a payload to the victim's machine while avoiding detection by security tools?
# Options: {'A': 'Defense Evasion: Virtualization/Sandbox Evasion', 'B': 'Execution: Malicious File', 'C': 'Initial Access: Spearphishing Attachment', 'D': 'Execution: Command and Scripting'}
# Correct answer: Initial Access: Spearphishing Attachment
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using malicious documents to deliver a payload to the victim's machine while avoiding detection by security tools?
# Options:
# A: Defense Evasion: Virtualization/Sandbox Evasion
# B: Execution: Malicious File
# C: Initial Access: Spearphishing Attachment
# D: Execution: Command and Scripting
# The correct answer is Initial Access: Spearphishing Attachment.
# Processing question: Which MITRE ATT&CK technique involves an attacker using stolen credentials to access a victim's system without raising suspicion?
# Options: {'A': 'Brute Force (T1110)', 'B': 'Valid Accounts (T1078)', 'C': 'Credential Dumping (T1003)', 'D': 'Account Manipulation (T1098)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker using stolen credentials to access a victim's system without raising suspicion?
# Options:
# A: Brute Force (T1110)
# B: Valid Accounts (T1078)
# C: Credential Dumping (T1003)
# D: Account Manipulation (T1098)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary using software tools to map and scan targets for vulnerabilities?
# Options: {'A': '1. Reconnaissance (T1592 - Network Scanning)', 'B': '2. Exploit Public-Facing Application (T1190)', 'C': '3. Data Staged (T1074)', 'D': '4. Command and Control (T1043 - Commonly Used Port)'}
# Correct answer: 1. Reconnaissance (T1592 - Network Scanning)
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using software tools to map and scan targets for vulnerabilities?
# Options:
# A: 1. Reconnaissance (T1592 - Network Scanning)
# B: 2. Exploit Public-Facing Application (T1190)
# C: 3. Data Staged (T1074)
# D: 4. Command and Control (T1043 - Commonly Used Port)
# The correct answer is 1. Reconnaissance (T1592 - Network Scanning).
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating security settings in order to avoid detection while carrying out malicious activities?
# Options: {'A': 'Masquerading (T1036)', 'B': 'Obfuscated Files or Information (T1027)', 'C': 'Credential Dumping (T1003)', 'D': 'Defense Evasion (Tactic)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary manipulating security settings in order to avoid detection while carrying out malicious activities?
# Options:
# A: Masquerading (T1036)
# B: Obfuscated Files or Information (T1027)
# C: Credential Dumping (T1003)
# D: Defense Evasion (Tactic)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary using a software vulnerability to gain unauthorized access to a system?
# Options: {'A': 'Spearphishing Attachment (T1193)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Exploitation for Client Execution (T1203)', 'D': 'Exploit Public-Facing Application (T1190)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using a software vulnerability to gain unauthorized access to a system?
# Options:
# A: Spearphishing Attachment (T1193)
# B: Exploit Public-Facing Application (T1190)
# C: Exploitation for Client Execution (T1203)
# D: Exploit Public-Facing Application (T1190)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves the use of a trusted relationship to compromise the target organization's network?
# Options: {'A': 'Reconnaissance over the internet (T1593 - Perform Eavesdropping)', 'B': 'Impersonation (T1560.001 - Spearphishing Attachment)', 'C': 'Valid Accounts (T1078 - Valid Accounts)', 'D': 'Trusted Relationship Exploitation (T1199 - Trusted Relationship)'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves the use of a trusted relationship to compromise the target organization's network?
# Options:
# A: Reconnaissance over the internet (T1593 - Perform Eavesdropping)
# B: Impersonation (T1560.001 - Spearphishing Attachment)
# C: Valid Accounts (T1078 - Valid Accounts)
# D: Trusted Relationship Exploitation (T1199 - Trusted Relationship)
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an adversary utilizing a software vulnerability to access privileged information or execute code on a target system?
# Options: {'A': 'Network Service Scanning (T1046)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Exploitation for Privilege Escalation (T1068)', 'D': 'Credential Dumping (T1003)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary utilizing a software vulnerability to access privileged information or execute code on a target system?
# Options:
# A: Network Service Scanning (T1046)
# B: Exploit Public-Facing Application (T1190)
# C: Exploitation for Privilege Escalation (T1068)
# D: Credential Dumping (T1003)
# The correct answer is C.
# Processing question: In the context of MITRE ATT&CK (Enterprise), which technique involves an adversary manipulating files using legitimate software, such as PowerShell, to avoid detection?
# Options: {'A': 'Process Injection', 'B': 'Scripting', 'C': 'Obfuscated Files or Information', 'D': 'Deobfuscate/Decode Files or Information'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK (Enterprise), which technique involves an adversary manipulating files using legitimate software, such as PowerShell, to avoid detection?
# Options:
# A: Process Injection
# B: Scripting
# C: Obfuscated Files or Information
# D: Deobfuscate/Decode Files or Information
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves gaining access to a network by exploiting a vulnerability in a web server?
# Options: {'A': ' A. T1190 - Exploit Public-Facing Application', 'B': ' B. T1566.001 - Phishing: Spearphishing Attachment', 'C': ' C. T1078 - Valid Accounts', 'D': ' D. T1078.003 - Domain Accounts'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves gaining access to a network by exploiting a vulnerability in a web server?
# Options:
# A:  A. T1190 - Exploit Public-Facing Application
# B:  B. T1566.001 - Phishing: Spearphishing Attachment
# C:  C. T1078 - Valid Accounts
# D:  D. T1078.003 - Domain Accounts
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an attacker using stolen credentials to log into a victim's email account and exfiltrate sensitive data?
# Options: {'A': 'Account Discovery (T1087)', 'B': 'Phishing (T1566.001)', 'C': 'Credential Dumping (T1003)', 'D': 'Exfiltration Over Command and Control Channel (T1041)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker using stolen credentials to log into a victim's email account and exfiltrate sensitive data?
# Options:
# A: Account Discovery (T1087)
# B: Phishing (T1566.001)
# C: Credential Dumping (T1003)
# D: Exfiltration Over Command and Control Channel (T1041)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary injecting and executing code in a different process?
# Options: {'A': 'Spoofing', 'B': 'Lateral Movement', 'C': 'Process Injection', 'D': 'Exfiltration'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary injecting and executing code in a different process?
# Options:
# A: Spoofing
# B: Lateral Movement
# C: Process Injection
# D: Exfiltration
# The correct answer is C.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves a threat actor creating a new account on a system using legitimate account management functions such as "net user" or "useradd"?
# Options: {'A': 'Credential Dumping (T1003 - Credential Dumping)', 'B': 'Valid Accounts (T1078 - Valid Accounts)', 'C': 'Account Manipulation (T1098 - Account Manipulation)', 'D': 'New Accounts (T1136 - Create Account)'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves a threat actor creating a new account on a system using legitimate account management functions such as "net user" or "useradd"?
# Options:
# A: Credential Dumping (T1003 - Credential Dumping)
# B: Valid Accounts (T1078 - Valid Accounts)
# C: Account Manipulation (T1098 - Account Manipulation)
# D: New Accounts (T1136 - Create Account)
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an adversary persuading an individual to reveal sensitive information by impersonating a trustworthy entity?
# Options: {'A': 'Spearphishing', 'B': 'Phishing with Trusted Service Provider', 'C': 'Phishing for Information', 'D': 'Pretexting'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary persuading an individual to reveal sensitive information by impersonating a trustworthy entity?
# Options:
# A: Spearphishing
# B: Phishing with Trusted Service Provider
# C: Phishing for Information
# D: Pretexting
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an adversary sending emails with malicious attachments to deceive victims into executing the attachment?
# Options: {'A': '(A) Phishing (T1566.001)', 'B': '(B) Spearphishing Attachment (T1566.001)', 'C': '(C) Spearphishing Link (T1566.002)', 'D': '(D) Drive-by Compromise (T1189)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary sending emails with malicious attachments to deceive victims into executing the attachment?
# Options:
# A: (A) Phishing (T1566.001)
# B: (B) Spearphishing Attachment (T1566.001)
# C: (C) Spearphishing Link (T1566.002)
# D: (D) Drive-by Compromise (T1189)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK Enterprise technique involves an adversary using stolen credentials?
# Options: {'A': 'Process Discovery (T1057) - Discovery', 'B': 'Valid Accounts (T1078) - Discovery', 'C': 'Credential Dumping (T1003) - Collection', 'D': 'Credential Access (T1078) - Collection'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK Enterprise technique involves an adversary using stolen credentials?
# Options:
# A: Process Discovery (T1057) - Discovery
# B: Valid Accounts (T1078) - Discovery
# C: Credential Dumping (T1003) - Collection
# D: Credential Access (T1078) - Collection
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique is most likely being described in the text?
# Options: {'A': 'nan', 'B': 'nan', 'C': 'nan', 'D': 'nan'}
# Correct answer: nan
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique is most likely being described in the text?
# Options:
# A: nan
# B: nan
# C: nan
# D: nan
# The correct answer is nan.
# Processing question: A. T1071 - Application Layer Protocol
# Options: {'A': 'nan', 'B': 'nan', 'C': 'nan', 'D': 'nan'}
# Correct answer: nan
# Generated text: Answer the following multiple-choice question.
# A. T1071 - Application Layer Protocol
# Options:
# A: nan
# B: nan
# C: nan
# D: nan
# The correct answer is nan.
# Processing question: B. T1083 - File and Directory Discovery
# Options: {'A': 'nan', 'B': 'nan', 'C': 'nan', 'D': 'nan'}
# Correct answer: nan
# Generated text: Answer the following multiple-choice question.
# B. T1083 - File and Directory Discovery
# Options:
# A: nan
# B: nan
# C: nan
# D: nan
# The correct answer is nan.
# Processing question: C. T1059.001 - Command and Scripting Interpreter: PowerShell
# Options: {'A': 'nan', 'B': 'nan', 'C': 'nan', 'D': 'nan'}
# Correct answer: nan
# Generated text: Answer the following multiple-choice question.
# C. T1059.001 - Command and Scripting Interpreter: PowerShell
# Options:
# A: nan
# B: nan
# C: nan
# D: nan
# The correct answer is nan.
# Processing question: D. T1003.001 - OS Credential Dumping
# Options: {'A': 'C', 'B': 'T1083 - File and Directory Discovery is commonly used to gather information about files and directories on a system, which aligns with the behavior described in the text. The other options are less relevant to the context provided.', 'C': 'nan', 'D': 'nan'}
# Correct answer: nan
# Generated text: Answer the following multiple-choice question.
# D. T1003.001 - OS Credential Dumping
# Options:
# A: C
# B: T1083 - File and Directory Discovery is commonly used to gather information about files and directories on a system, which aligns with the behavior described in the text. The other options are less relevant to the context provided.
# C: nan
# D: nan
# The correct answer is nan.
# Processing question: Which MITRE ATT&CK technique involves an adversary abusing Windows Management Instrumentation (WMI) for execution, persistence, and defense evasion?
# Options: {'A': 'Process Injection - Dynamic-link Library Injection', 'B': 'Accessibility Features', 'C': 'Process Discovery - System Network Connections Discovery', 'D': 'Execution through API'}
# Correct answer: Process Injection - Dynamic-link Library Injection
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary abusing Windows Management Instrumentation (WMI) for execution, persistence, and defense evasion?
# Options:
# A: Process Injection - Dynamic-link Library Injection
# B: Accessibility Features
# C: Process Discovery - System Network Connections Discovery
# D: Execution through API
# The correct answer is Process Injection - Dynamic-link Library Injection.
# Processing question: Which MITRE ATT&CK technique involves an adversary abusing system utilities to transfer, launch, or execute malicious payloads on a victim's machine?
# Options: {'A': 'Process Injection - T1055', 'B': 'Trusted Relationship - T1199', 'C': 'Exploitation for Client Execution - T1203', 'D': 'Execution through API - T1106'}
# Correct answer: Process Injection - T1055
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary abusing system utilities to transfer, launch, or execute malicious payloads on a victim's machine?
# Options:
# A: Process Injection - T1055
# B: Trusted Relationship - T1199
# C: Exploitation for Client Execution - T1203
# D: Execution through API - T1106
# The correct answer is Process Injection - T1055.
# Processing question: Which MITRE ATT&CK technique involves the use of a software tool that enables the remote monitoring of keystrokes on a compromised system?
# Options: {'A': '(A) Keylogger / T1125', 'B': 'Data Encoding / T1132', 'C': 'Remote Access Tools / T1219', 'D': 'Valid Accounts / T1078'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves the use of a software tool that enables the remote monitoring of keystrokes on a compromised system?
# Options:
# A: (A) Keylogger / T1125
# B: Data Encoding / T1132
# C: Remote Access Tools / T1219
# D: Valid Accounts / T1078
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an attacker manipulating the timing and content of network traffic to deceive an adversary?
# Options: {'A': 'T1560 - Archive Collected Data', 'B': 'T1498 - Network Denial of Service', 'C': 'T1588 - Compromise Infrastructure', 'D': 'T1562 - Impair Defenses'}
# Correct answer: T1588 - Compromise Infrastructure
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker manipulating the timing and content of network traffic to deceive an adversary?
# Options:
# A: T1560 - Archive Collected Data
# B: T1498 - Network Denial of Service
# C: T1588 - Compromise Infrastructure
# D: T1562 - Impair Defenses
# The correct answer is T1588 - Compromise Infrastructure.
# Processing question: Within the context of MITRE ATT&CK Enterprise, which technique involves the use of trusted software applications to perform malicious activities without directly executing adversary-controlled code?
# Options: {'A': 'Process Hollowing (T1093)', 'B': 'Trusted Relationship (T1199)', 'C': 'Software Packing (T1045)', 'D': 'Process Injection (T1055)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Within the context of MITRE ATT&CK Enterprise, which technique involves the use of trusted software applications to perform malicious activities without directly executing adversary-controlled code?
# Options:
# A: Process Hollowing (T1093)
# B: Trusted Relationship (T1199)
# C: Software Packing (T1045)
# D: Process Injection (T1055)
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary using a program to falsify the apparent source of data?
# Options: {'A': 'Process Injection (T1055) - Process Injection', 'B': 'Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Other Network Medium', 'C': 'Valid Accounts (T1078) - Valid Accounts', 'D': 'Spearphishing Attachment (T1193) - Phishing'}
# Correct answer: Lateral Movement (T1070) - Lateral Movement
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using a program to falsify the apparent source of data?
# Options:
# A: Process Injection (T1055) - Process Injection
# B: Exfiltration Over Alternative Protocol (T1048) - Exfiltration Over Other Network Medium
# C: Valid Accounts (T1078) - Valid Accounts
# D: Spearphishing Attachment (T1193) - Phishing
# The correct answer is Lateral Movement (T1070) - Lateral Movement.
# Processing question: Which MITRE ATT&CK technique involves an adversary sending emails with malicious attachments to targeted individuals to gain access to the victim's system?
# Options: {'A': 'Spearphishing Attachment', 'B': 'Spearphishing Link', 'C': 'Drive-by Compromise', 'D': 'Man-in-the-Middle'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary sending emails with malicious attachments to targeted individuals to gain access to the victim's system?
# Options:
# A: Spearphishing Attachment
# B: Spearphishing Link
# C: Drive-by Compromise
# D: Man-in-the-Middle
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary compromising the integrity of data by making unauthorized modifications to data through techniques such as data poisoning or data corruption?
# Options: {'A': 'Data Manipulation (T1565.001)', 'B': 'Exploit Public-Facing Application (T1190)', 'C': 'Component Firmware (T801)', 'D': 'Application Layer Protocol (T1071)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary compromising the integrity of data by making unauthorized modifications to data through techniques such as data poisoning or data corruption?
# Options:
# A: Data Manipulation (T1565.001)
# B: Exploit Public-Facing Application (T1190)
# C: Component Firmware (T801)
# D: Application Layer Protocol (T1071)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK Enterprise technique involves an adversary sending emails with malicious attachments to targeted individuals within an organization?
# Options: {'A': 'Spearphishing Attachment', 'B': 'Phishing for Information', 'C': 'Spearphishing Link', 'D': 'Spearphishing Service'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# ...
# Options: {'A': 'Timing-Based Port Scan (T1046 - Network Service Scanning)', 'B': 'Data Staging (T1074 - Data Staging)', 'C': 'Obfuscated Files or Information (T1027 - Obfuscated Files or Information)', 'D': 'Network Sniffing (T1040 - Network Sniffing)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating the timing of network traffic to mask their presence?
# Options:
# A: Timing-Based Port Scan (T1046 - Network Service Scanning)
# B: Data Staging (T1074 - Data Staging)
# C: Obfuscated Files or Information (T1027 - Obfuscated Files or Information)
# D: Network Sniffing (T1040 - Network Sniffing)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an adversary gaining unauthorized access to a system through a compromised external service?
# Options: {'A': 'Square', 'B': 'Man in the Middle (T1557.002 - Steal Web Session Cookie)', 'C': 'Password Spraying (T1110 - Brute Force)', 'D': 'Submarine Phishing (T1567.004 - Spearphishing Attachment)'}
# Correct answer: Man in the Middle (T1557.002 - Steal Web Session Cookie)
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary gaining unauthorized access to a system through a compromised external service?
# Options:
# A: Square
# B: Man in the Middle (T1557.002 - Steal Web Session Cookie)
# C: Password Spraying (T1110 - Brute Force)
# D: Submarine Phishing (T1567.004 - Spearphishing Attachment)
# The correct answer is Man in the Middle (T1557.002 - Steal Web Session Cookie).
# Processing question: Which MITRE ATT&CK technique involves an actor using a man-in-the-middle attack to intercept and modify communication between devices on a network?
# Options: {'A': ' A. ARP Spoofing (T1043 - Commonly Used Port)', 'B': 'B. Data Obfuscation (T1001 - Data Obfuscation)', 'C': 'C. Network Sniffing (T1040 - Network Sniffing)', 'D': 'D. Masquerading (T1036 - Masquerading)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an actor using a man-in-the-middle attack to intercept and modify communication between devices on a network?
# Options:
# A:  A. ARP Spoofing (T1043 - Commonly Used Port)
# B: B. Data Obfuscation (T1001 - Data Obfuscation)
# C: C. Network Sniffing (T1040 - Network Sniffing)
# D: D. Masquerading (T1036 - Masquerading)
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an adversary persuading a user to click on a malicious link in an email, leading to exploitation of a system vulnerability?
# Options: {'A': 'Spearphishing Link', 'B': 'Spearphishing Attachment', 'C': 'Phishing', 'D': 'Drive-by Compromise'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary persuading a user to click on a malicious link in an email, leading to exploitation of a system vulnerability?
# Options:
# A: Spearphishing Link
# B: Spearphishing Attachment
# C: Phishing
# D: Drive-by Compromise
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary manipulating the timing, functions, or outputs of ICS systems to thwart the detection of malicious activities?
# Options: {'A': 'Process Injection (T1055) - Process Hollowing', 'B': 'Obfuscated Files or Information (T1027) - Software Packing', 'C': 'Software Manipulation (T1497) - Falsify Content', 'D': 'Tampering with Data in Transit (T1562.001) - Data Manipulation'}
# Correct answer: T1498 - Deliver Malicious App via Authorized App Store
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating the timing, functions, or outputs of ICS systems to thwart the detection of malicious activities?
# Options:
# A: Process Injection (T1055) - Process Hollowing
# B: Obfuscated Files or Information (T1027) - Software Packing
# C: Software Manipulation (T1497) - Falsify Content
# D: Tampering with Data in Transit (T1562.001) - Data Manipulation
# The correct answer is T1498 - Deliver Malicious App via Authorized App Store.
# Processing question: Which MITRE ATT&CK technique involves an adversary compromising a network device to enable command and control communication?
# Options: {'A': 'Spearphishing Attachment (T1193)', 'B': 'Domain Generation Algorithms (T1568.002)', 'C': 'Remote Access Tools (T1219)', 'D': 'Hardware Additions (T1200)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary compromising a network device to enable command and control communication?
# Options:
# A: Spearphishing Attachment (T1193)
# B: Domain Generation Algorithms (T1568.002)
# C: Remote Access Tools (T1219)
# D: Hardware Additions (T1200)
# The correct answer is C.
# Processing question: Which MITRE ATT&CK technique involves an attacker using a keylogger to capture keystrokes on a victim's machine in the Enterprise platform?
# Options: {'A': 'Keylogging (T1056)', 'B': 'Credential Dumping (T1003)', 'C': 'Spearphishing Attachment (T1193)', 'D': 'Steal Web Session Cookie (T1539)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker using a keylogger to capture keystrokes on a victim's machine in the Enterprise platform?
# Options:
# A: Keylogging (T1056)
# B: Credential Dumping (T1003)
# C: Spearphishing Attachment (T1193)
# D: Steal Web Session Cookie (T1539)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique involves an attacker sending a specially crafted email to execute malicious code on a target system without user interaction?
# Options: {'A': 'Brute Force (T1110) - Password Cracking', 'B': 'Phishing (T1566.001) - Spearphishing Attachment', 'C': 'Exfiltration Over Alternative Protocol (T1048) - Archive Collected Data', 'D': 'Execution through API (T1106) - Execution through API'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an attacker sending a specially crafted email to execute malicious code on a target system without user interaction?
# Options:
# A: Brute Force (T1110) - Password Cracking
# B: Phishing (T1566.001) - Spearphishing Attachment
# C: Exfiltration Over Alternative Protocol (T1048) - Archive Collected Data
# D: Execution through API (T1106) - Execution through API
# The correct answer is B.
# Processing question: Which MITRE ATT&CK technique involves an adversary sending malicious emails with a weaponized attachment specifically tailored to the recipient's interests or position within an organization?
# Options: {'A': 'T1566.001 - Spearphishing Attachment', 'B': 'T1204.002 - User Execution', 'C': 'T1083 - File and Directory Discovery', 'D': 'T1485 - Data Destruction'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary sending malicious emails with a weaponized attachment specifically tailored to the recipient's interests or position within an organization?
# Options:
# A: T1566.001 - Spearphishing Attachment
# B: T1204.002 - User Execution
# C: T1083 - File and Directory Discovery
# D: T1485 - Data Destruction
# The correct answer is A.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using valid accounts to log into a network service and then using those services to move laterally within the network?
# Options: {'A': 'Valid Accounts (T1078)', 'B': 'Remote Services (T1021)', 'C': 'Exploitation for Privilege Escalation (T1068)', 'D': 'External Remote Services (T1133)'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using valid accounts to log into a network service and then using those services to move laterally within the network?
# Options:
# A: Valid Accounts (T1078)
# B: Remote Services (T1021)
# C: Exploitation for Privilege Escalation (T1068)
# D: External Remote Services (T1133)
# The correct answer is A.
# Processing question: Which MITRE ATT&CK technique is commonly associated with threat actors attempting to establish a foothold in a network after compromising an initial system?
# Options: {'A': 'Execution through Module Load', 'B': 'Valid Accounts', 'C': 'Valid Accounts: Domain Accounts', 'D': 'Exploitation for Credential Access'}
# Correct answer: Exploitation for Credential Access
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique is commonly associated with threat actors attempting to establish a foothold in a network after compromising an initial system?
# Options:
# A: Execution through Module Load
# B: Valid Accounts
# C: Valid Accounts: Domain Accounts
# D: Exploitation for Credential Access
# The correct answer is Exploitation for Credential Access.
# Processing question: In the context of MITRE ATT&CK Enterprise, which technique involves an adversary using a signed binary proxy execution to evade defenses?
# Options: {'A': 'Credential Dumping (T1003 - Credential Dumping)', 'B': 'Execution through API (T1106 - Execution through API)', 'C': 'Proxy (T1090 - Proxy)', 'D': 'Signed Binary Proxy Execution (T1218.009 - Signed Binary Proxy Execution)'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK Enterprise, which technique involves an adversary using a signed binary proxy execution to evade defenses?
# Options:
# A: Credential Dumping (T1003 - Credential Dumping)
# B: Execution through API (T1106 - Execution through API)
# C: Proxy (T1090 - Proxy)
# D: Signed Binary Proxy Execution (T1218.009 - Signed Binary Proxy Execution)
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an adversary using social engineering to manipulate individuals into divulging information or performing actions that compromise security?
# Options: {'A': 'Spearphishing Attachment (T1193)', 'B': 'Phishing (T1566)', 'C': 'Phishing for Information (T1598)', 'D': 'Spearphishing Link (T1192)'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary using social engineering to manipulate individuals into divulging information or performing actions that compromise security?
# Options:
# A: Spearphishing Attachment (T1193)
# B: Phishing (T1566)
# C: Phishing for Information (T1598)
# D: Spearphishing Link (T1192)
# The correct answer is B.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary gaining access to a victim's system by sending a malicious email with an attachment containing a payload designed to exploit a vulnerability in the email client?
# Options: {'A': 'Execution: Malicious Code (T1203)', 'B': 'Masquerading (T1036)', 'C': 'Exploit Public-Facing Application (T1190)', 'D': 'Spearphishing Attachment (T1193)'}
# Correct answer: D
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary gaining access to a victim's system by sending a malicious email with an attachment containing a payload designed to exploit a vulnerability in the email client?
# Options:
# A: Execution: Malicious Code (T1203)
# B: Masquerading (T1036)
# C: Exploit Public-Facing Application (T1190)
# D: Spearphishing Attachment (T1193)
# The correct answer is D.
# Processing question: Which MITRE ATT&CK technique involves an adversary manipulating the execution flow of a process to bypass security mechanisms and achieve persistence?
# Options: {'A': 'Process Injection - T1055', 'B': 'Defense Evasion - T1562', 'C': 'Execution Guardrails - T1480', 'D': 'Exploit Public-Facing Application - T1190'}
# Correct answer: A
# Generated text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary manipulating the execution flow of a process to bypass security mechanisms and achieve persistence?
# Options:
# A: Process Injection - T1055
# B: Defense Evasion - T1562
# C: Execution Guardrails - T1480
# D: Exploit Public-Facing Application - T1190
# The correct answer is A.
# Processing question: Based on the provided document related to Cyber Threat Intelligence in the context of MITRE ATT&CK, which technique is commonly associated with the ID T1560 - Archive Collected Data?
# Options: {'A': 'SYSTEM SERVICE DISCOVERY', 'B': 'ARCHIVE COLLECTED DATA', 'C': 'BYPASS USER ACCOUNT CONTROL', 'D': 'INPUT CAPTURE'}
# Correct answer: B
# Generated text: Answer the following multiple-choice question.
# Based on the provided document related to Cyber Threat Intelligence in the context of MITRE ATT&CK, which technique is commonly associated with the ID T1560 - Archive Collected Data?
# Options:
# A: SYSTEM SERVICE DISCOVERY
# B: ARCHIVE COLLECTED DATA
# C: BYPASS USER ACCOUNT CONTROL
# D: INPUT CAPTURE
# The correct answer is B.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using automated tools to collect data from a compromised system without needing to install any new software?
# Options: {'A': 'Process Discovery (T1057) - Process Discovery', 'B': 'Data Staging (T1074) - Data Staging', 'C': 'Data from Information Repositories (T1213) - Data from Information Repositories', 'D': 'Remote System Discovery (T1018) - Remote System Discovery'}
# Correct answer: Remote System Discovery (T1018) - Remote System Discovery
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using automated tools to collect data from a compromised system without needing to install any new software?
# Options:
# A: Process Discovery (T1057) - Process Discovery
# B: Data Staging (T1074) - Data Staging
# C: Data from Information Repositories (T1213) - Data from Information Repositories
# D: Remote System Discovery (T1018) - Remote System Discovery
# The correct answer is Remote System Discovery (T1018) - Remote System Discovery.
# Processing question: In the context of MITRE ATT&CK techniques, which tactic involves adversaries using tools to collect and exfiltrate data over a network, such as using Remote Desktop Protocol or TeamViewer?
# Options: {'A': 'Execution', 'B': 'Exfiltration', 'C': 'Collection', 'D': 'Lateral Movement'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK techniques, which tactic involves adversaries using tools to collect and exfiltrate data over a network, such as using Remote Desktop Protocol or TeamViewer?
# Options:
# A: Execution
# B: Exfiltration
# C: Collection
# D: Lateral Movement
# The correct answer is C.
# Processing question: In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using social engineering to manipulate individuals into performing actions or divulging confidential information?
# Options: {'A': 'Spearphishing Attachment (T1566.001)', 'B': 'Phishing (T1566)', 'C': 'Spearphishing Link (T1566.002)', 'D': 'Remote File Copy (T1105)'}
# Correct answer: C
# Generated text: Answer the following multiple-choice question.
# In the context of MITRE ATT&CK for Enterprise, which technique involves an adversary using social engineering to manipulate individuals into performing actions or divulging confidential information?
# Options:
# A: Spearphishing Attachment (T1566.001)
# B: Phishing (T1566)
# C: Spearphishing Link (T1566.002)
# D: Remote File Copy (T1105)
# The correct answer is C.
# Formatted text: Answer the following multiple-choice question.
# Which MITRE ATT&CK technique involves an adversary directly interacting with a victim to manipulate them into divulging confidential information?
# Options:
# A: Spearphishing Attachment (T1193)
# B: Social Engineering (T1140)
# C: Remote Access Tools (T1219)
# D: Man-in-the-Middle Attack (T1557)
# The correct answer is B.

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and evaluation subsets
dataset_split = formatted_dataset.train_test_split(test_size=0.2, seed=42)

# Extract training and evaluation subsets
train_dataset = dataset_split["train"]
eval_dataset = dataset_split["test"]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
from sklearn.metrics import accuracy_score

# Define a metrics calculation function
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = predictions.argmax(axis=-1)  # For classification tasks
    accuracy = accuracy_score(labels, predictions)
    return {"accuracy": accuracy}

# Define training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    warmup_steps=5,
    num_train_epochs=5,  # Set number of epochs to 3
    learning_rate=1e-4,
    fp16=not is_bfloat16_supported(),
    bf16=is_bfloat16_supported(),
    logging_steps=1,
    optim="adamw_8bit",
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs",
)

# Initialize SFTTrainer with compute_metrics
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    dataset_text_field="text",
    max_seq_length=512,  # Adjust as needed
    dataset_num_proc=2,
    packing=False,
    args=training_args,
    compute_metrics=compute_metrics,  # Add this line
)

# Train the model
trainer.train()
# Out:
# Map (num_proc=2):   0%|          | 0/2014 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/504 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 2,014 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 1,255
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='649' max='1255' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 649/1255 46:35 < 43:38, 0.23 it/s, Epoch 2.57/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.041000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.940700</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.936300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.968700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.918800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.758100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.758000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.364900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.307500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.269400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.163700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.162200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.066700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.180600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.909600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.128900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.037300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.009100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.890700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.968900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.153700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.868300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.873600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.028000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.918600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.837300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.849600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.812500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.155600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.858800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.815800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.892600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.917600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.860500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.817700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.807500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.735800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.736600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.734200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.843400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.833700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.803300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.828700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.787200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.738200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.876200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.747200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.696100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.806800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.828800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.641400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.622900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.655300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.874800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.685900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.688400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.630700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.693100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.892200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.623700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.662300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.755600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.659000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.676500</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.648300</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.718300</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.713400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.893900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.801800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.645100</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.602100</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.885300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.764500</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.765900</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.773600</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.719600</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.742500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.675800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.640200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.766500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.640800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.716100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.718200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.686800</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.654200</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.635200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.714200</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.756000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.711700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.938300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.579300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.734100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.789700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.649300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.672100</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.694700</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.602700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.696000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.677800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.590100</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.714400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.773600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.750800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.728200</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.735900</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.694500</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.622100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.668900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.783800</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.660300</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.666400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.623300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.742000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.648900</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.608700</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.610800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.704300</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.635000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.646900</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.557500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.624000</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.592800</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.663300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.623300</td>
#     </tr>
#     <div>
#
#       <progress value='1255' max='1255' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1255/1255 1:30:34, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.041000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.940700</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.936300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.968700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.918800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.758100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.758000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.364900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.307500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.269400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.163700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.162200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.066700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.180600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.909600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.128900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.037300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.009100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.041300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.890700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.968900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.153700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.868300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.873600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.028000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.918600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.837300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.849600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.812500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.155600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.858800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.815800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.892600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.917600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.860500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.817700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.807500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.735800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.736600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.734200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.843400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.833700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.803300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.828700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.787200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.738200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.876200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.747200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.696100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.806800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.828800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.641400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.622900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.655300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.874800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.685900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.688400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.630700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.693100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.892200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.623700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.662300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.755600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.659000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.676500</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.648300</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.718300</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.713400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.893900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.801800</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.645100</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.602100</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.885300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.764500</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.765900</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.773600</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.719600</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.742500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.675800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.640200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.766500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.640800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.716100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.718200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.686800</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.654200</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.635200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.714200</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.756000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.711700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.938300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.579300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.734100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.789700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.649300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.672100</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.694700</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.602700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.696000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.677800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.590100</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.714400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.773600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.750800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.728200</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.735900</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.694500</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.622100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.668900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.783800</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.660300</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.666400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.623300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.742000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.648900</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.608700</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.610800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.704300</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.635000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.646900</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.557500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.624000</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.592800</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.663300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.623300</td>
#     </tr>
#     <tr>
#       <td>
# TrainOutput(global_step=1255, training_loss=0.5240351760767371, metrics={'train_runtime': 5445.5015, 'train_samples_per_second': 1.849, 'train_steps_per_second': 0.23, 'total_flos': 4.336572068428186e+16, 'train_loss': 0.5240351760767371, 'epoch': 4.985104270109235})

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save_pretrained("/content/drive/MyDrive/modeliiiiiiy") # Local saving
tokenizer.save_pretrained("/content/drive/MyDrive/modeliiiiiiy")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('/content/drive/MyDrive/modeliiiiiiy/tokenizer_config.json',
#  '/content/drive/MyDrive/modeliiiiiiy/special_tokens_map.json',
#  '/content/drive/MyDrive/modeliiiiiiy/tokenizer.json')
